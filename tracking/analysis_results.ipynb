# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 8]

sys.path.append('A:\AI\Project\OSTrack')
from lib.test.analysis.plot_results import plot_results, print_results, \
	print_per_sequence_results, print_results_per_video, plot_success_per_sequence, plot_iou_curve_per_video, \
	visualize_sequence
from lib.test.evaluation import get_dataset, trackerlist
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_name = 'lasot'

trackers = []
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_5-5_T4_post', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-5-5-T4-ep200'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_8-8_T4_post', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-8-8-T4-ep180'))
# # trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_5-5_T4_post_freeze', dataset_name=dataset_name,
# #                             run_ids=None, display_name='OSTrackMem256-post-5-5-T4-freeze-ep20'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_5-5_T4_post_pftest', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-5-5-T4-pfreeze-ep100'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_8-8_T4_post_pftest', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-8-8-T4-pfreeze-ep200'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_8-8_T4_post_minf', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-8-8-T4-minf-ep20'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_5-5_T4_post_minf_postTE', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-5-5-T4-minf-postTE-ep00-noTE'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_5-5_T4_post_minf_postTE', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-post-5-5-T4-minf-postTE-ep40'))
trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300', dataset_name=dataset_name,
                            run_ids=None, display_name='OSTrackT256'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vit_tiny_256_mae_ce_32x4_ep300_mem_V1.0', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-V1.0-ep200'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='OSTrack_mem_55_roi5_hy1.0_V1.1', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrackMem256-V1.1-ep200'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='OSTrack_mem_55_roi8_hy1.0_V1.4', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrack_mem_55_roi8_hy1.0_V1.4-ep200'))
trackers.extend(trackerlist(name='ostrack', parameter_name='OSTrack_mem_55_roi8_hy1.0_pee_V1.12', dataset_name=dataset_name,
                            run_ids=None, display_name='OSTrack_mem_55_roi8_hy1.0_pee_V1.12-ep200'))
trackers.extend(trackerlist(name='ostrack', parameter_name='OSTrack_mem_55_roi8_hy1.0_pee_V1.13', dataset_name=dataset_name,
                            run_ids=None, display_name='OSTrack_mem_55_roi8_hy1.0_pee_V1.13-ep200'))
trackers.extend(trackerlist(name='ostrack', parameter_name='OSTrack_mem_22_roi8_hy1.0_pee_V1.14', dataset_name=dataset_name,
                            run_ids=None, display_name='OSTrack_mem_22_roi8_hy1.0_pee_V1.14-ep100'))
trackers.extend(trackerlist(name='ostrack', parameter_name='OSTrack_mem_88_roi8_hy1.0_pee_V1.15', dataset_name=dataset_name,
                            run_ids=None, display_name='OSTrack_mem_88_roi8_hy1.0_pee_V1.15-ep100'))
# trackers.extend(trackerlist(name='ostrack', parameter_name='vitb_384_mae_ce_32x4_ep300', dataset_name=dataset_name,
#                             run_ids=None, display_name='OSTrack384'))

dataset = get_dataset(dataset_name)
# plot_results(trackers, dataset, dataset_name, merge_results=True, plot_types=('success', 'prec'),
#              skip_missing_seq=False, force_evaluation=True, plot_bin_gap=0.05, exclude_invalid_frames=False)
print_results(trackers, dataset, dataset_name, merge_results=True, plot_types=('success', 'prec', 'norm_prec'))
print_results_per_video(trackers, dataset, dataset_name, merge_results=True, plot_types=('success', 'prec', 'norm_prec'),
                        per_video=True, force_evaluation=True)
print_per_sequence_results(trackers, dataset, dataset_name, merge_results=True, plot_types=('success', 'prec', 'norm_prec'))
# plot_success_per_sequence(trackers, dataset, dataset_name)
# plot_iou_curve_per_video(trackers, dataset, dataset_name)
# Out:
# 100%|██████████| 280/280 [00:41<00:00,  6.69it/s]
# Computed results over 280 / 280 sequences
#
# Reporting results over 280 / 280 sequences
#
# lasot                                          | AUC        | OP50       | OP75       | Precision    | Norm Precision    |
# OSTrackT256                                    | 66.08      | 77.41      | 64.46      | 70.47        | 75.81             |
# OSTrack_mem_55_roi8_hy1.0_pee_V1.12-ep200      | 66.26      | 77.94      | 64.47      | 71.00        | 76.33             |
# OSTrack_mem_55_roi8_hy1.0_pee_V1.13-ep200      | 66.26      | 77.94      | 64.47      | 71.00        | 76.33             |
# OSTrack_mem_22_roi8_hy1.0_pee_V1.14-ep100      | 65.83      | 77.34      | 64.09      | 70.43        | 75.77             |
# OSTrack_mem_88_roi8_hy1.0_pee_V1.15-ep100      | 66.44      | 77.97      | 64.74      | 70.92        | 76.38             |
# 100%|██████████| 280/280 [00:30<00:00,  9.29it/s]
# Computed results over 280 / 280 sequences
#
# ...

# %%
# visualize_sequence(trackers[0], dataset, "bird-2", save_video=False)
visualize_sequence(trackers[1], dataset, "drone-7", save_video=False)
# Out:
# Visualizing sequence: drone-7...
# Saving output to: A:/AI/Project/OSTrack/lib/test/result_plots/visualization\drone-7
# Processed 50/2817 frames
# Processed 100/2817 frames
# Processed 150/2817 frames
# Processed 200/2817 frames
# Processed 250/2817 frames
# Processed 300/2817 frames
# Processed 350/2817 frames
# Processed 400/2817 frames
# Processed 450/2817 frames
# Processed 500/2817 frames
# Processed 550/2817 frames
# Processed 600/2817 frames
# Processed 650/2817 frames
# Processed 700/2817 frames
# Processed 750/2817 frames
# Processed 800/2817 frames
# Processed 850/2817 frames
# Processed 900/2817 frames
# Processed 950/2817 frames
# Processed 1000/2817 frames
# Processed 1050/2817 frames
# Processed 1100/2817 frames
# Processed 1150/2817 frames
# Processed 1200/2817 frames
# Processed 1250/2817 frames
# Processed 1300/2817 frames
# Processed 1350/2817 frames
# Processed 1400/2817 frames
# Processed 1450/2817 frames
# Processed 1500/2817 frames
# Processed 1550/2817 frames
# ...
